# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/toshiba_seqw/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            now=(float(ll[0])-time0)/1000000
            if now<60 and now>1:
                la.append(latency)
                cnt+=1
                total+=latency
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,18,4))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.0720990155933
# median 0.049
# 99th: 0.107
# 99.99th: 9.347
# 9.688

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel535_4k_randw_aged5/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 1.46610140463
# median 0.045
# 99th: 0.606
# 99.99th: 1125.273
# 2432.775

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel545s_seqw2/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.0499833306663
# median 0.046
# 99th: 0.104
# 99.99th: 2.619
# 6.252

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel545s_seq4krep4/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(5,4))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    #fs=35
    #plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    #plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)')
    ax1.set_ylabel('Latency(ms)')
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 5.26277076102
# median 0.086
# 99th: 106.945
# 99.99th: 198.596
# 266.667

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc4510bw_bw.log'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        for line in fp:
            ll=line.split(',')
            latency=float(ll[1])/1024
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0]))/1000
            if now<8000:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=20
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,7000,1000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(40,300,80))
    ax1.set_xlabel('Time(s)',fontsize=fs)
    ax1.set_ylabel('Bandwidth(MB/s)',fontsize=fs)
    ax1.plot(x,y,color='red',marker='+')
    #ax1.scatter(x,y,s=2,c='b',marker='o')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc4510_randw_64k_500/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(5,4))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    #fs=35
    #plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    #plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)')
    ax1.set_ylabel('Latency(ms)')
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 17.404823732
# median 0.22
# 99th: 217.872
# 99.99th: 802.71
# 1068.225

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel545s_randw_4k_80_full/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 4.22276603576
# median 0.052
# 99th: 55.91
# 99.99th: 400.247
# 596.457

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/sandisk_4k_randw/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 32.4295720511
# median 0.097
# 99th: 585.986
# 99.99th: 2078.532
# 3344.925

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel545s_seq4krep3/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(5,4))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    #fs=35
    #plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    #plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)')
    ax1.set_ylabel('Latency(ms)')
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.053402572765
# median 0.048
# 99th: 0.174
# 99.99th: 2.468
# 9.929

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/intel545s_seqr4k/rcd'
    sl=[]
    la=[]
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            now=(float(ll[0])-time0)/1000000
            if now<40:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print '99th:',laa[int(0.99*len(laa))]
    print '99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(211)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=30
    plt.xticks(fontsize=fs)
    plt.xticks(np.arange(0,41,10))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,11,4))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.show()
    rcd='/root/fusionRAID/results/intel545s_seqw4k/rcd'
    sl=[]
    la=[]
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            now=(float(ll[0])-time0)/1000000
            if now<40:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print '99th:',laa[int(0.99*len(laa))]
    print '99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    #fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(212)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=30
    plt.xticks(fontsize=fs)
    plt.xticks(np.arange(0,41,10))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,9,4))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    plt.show()
# Out:
# 99th: 0.364
# 99th: 7.714
# 10.261
# 99th: 0.188
# 99th: 7.036
# 9.334

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc4500_exchange_clean/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 25.5845626939
# median 0.259
# 99th: 335.375
# 99.99th: 720.308
# 950.923

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc4510_exchange_clean/rcd'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 6.03521596387
# median 0.132
# 99th: 107.18
# 99.99th: 380.004
# 443.75

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/home/ssd_new2_out'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        #time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0]))/1000000
            if now==0:
                print ll
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.958235378967
# median 0.465
# 99th: 8.726
# 99.99th: 96.988
# 100.028

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/home/ssd_new2_out3'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        #time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0]))/1000000
            if now==0:
                print ll
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 1.05341326433
# median 0.378
# 99th: 16.958
# 99.99th: 220.937
# 252.215

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/home/ssd_new2_out3'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 1.05341326433
# median 0.378
# 99th: 16.958
# 99.99th: 220.937
# 252.215

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/ssdraid5_prof_exchange_new2/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 10.1617036145
# median 1.17
# 99th: 136.154
# 99.99th: 1159.955
# 1400.912

# %%
import numpy as np
import matplotlib.pyplot as plt
st=0
ed=50
for iii in range(5):
    rcd='/home/ssd_new2_out'+str(iii)
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<ed and now>st:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    #print 'avg',float(total)/cnt
    #print 'median',laa[int(0.5*len(laa))]
    #print '99th:',laa[int(0.99*len(laa))]
    #print '99.99th:',laa[int(0.9999*len(laa))]
    #print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,2))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,81,20))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
for iii in range(1):
    rcd='/root/fusionRAID/results/ssdraid5_prof_exchange_new2/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<ed and now>st:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    #print 'avg',float(total)/cnt
    #print 'median',laa[int(0.5*len(laa))]
    #print '99th:',laa[int(0.99*len(laa))]
    #print '99.99th:',laa[int(0.9999*len(laa))]
    #print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,3))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,100,20))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-b746a4f4bfdd> in <module>()
#      14         for line in fp:
#      15             ll=line.split()
# ---> 16             latency=float(ll[1])/1000
#      17             la.append(latency)
#      18             cnt+=1
#
# IndexError: list index out of range

# %%
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/ssdraid5_prof_exchange_new2/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<500:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    #print 'avg',float(total)/cnt
    #print 'median',laa[int(0.5*len(laa))]
    #print '99th:',laa[int(0.99*len(laa))]
    #print '99.99th:',laa[int(0.9999*len(laa))]
    #print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,3))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def predict(queue):
    return queue*0.1+0.1
threshold=1
time0=float(958635434)
range_arr=[]
for iii in range(5):
    rcd='/home/ssd_out'+str(iii)
    with open(rcd,'r') as fp:
        f1=fp.readline()
        t0=float(f1.split()[0])
        if time0>t0:
            time0=t0
#print time0
for iii in range(5):
    rcd='/home/ssd_out'+str(iii)
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        #f1=fp.readline()
        #time0=float(f1.split()[0])
        #print time0
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now<2:
                if latency>predict(int(ll[2]))+threshold:
                    sl.append([now,now+float(latency)/1000])
    ss=sorted(sl,key=lambda x:x[0])
    #laa=sorted(la)
    #print ss
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    #print sr
    #print 'avg',float(total)/cnt
    #print 'median',laa[int(0.5*len(laa))]
    #print '99th:',laa[int(0.99*len(laa))]
    #print '99.99th:',laa[int(0.9999*len(laa))]
    #print laa[-1]
    range_arr.append(sr)
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    x.append(2.0)
    y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    plt.xticks(np.arange(0,2.1,0.2))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
for iii in range(1):
    rcd='/root/fusionRAID/results/ssdraid5_prof_exchange_new2/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now==0:
                print ll
            if now<2:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    #print 'avg',float(total)/cnt
    #print 'median',laa[int(0.5*len(laa))]
    #print '99th:',laa[int(0.99*len(laa))]
    #print '99.99th:',laa[int(0.9999*len(laa))]
    #print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(18,3))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    plt.xticks(np.arange(0,2.1,0.2))
    plt.yticks(fontsize=fs)
    plt.yticks(np.arange(0,100,50))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=1,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_final3_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#rr=200000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer(p,arr):
    for i in range(5):
        if p[2][i]==1:
            if hit(p[3],p[1],arr[i]):
                return 0
    return 1
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if not first and t>rr:
            #print line
            break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
                #single[disk].append([start[0],t,start[3]])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
for i in sort_whole:
    if i[0]!=cur:
        lats.append([cur,last[1]-start,ds,start])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            ret.append([j[3],j[3]+j[1]])
print float(cnt)/len(lats)
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
# Out:
# 0.0832495812395

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_final3_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        #if tag==14872:
            #print line
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if not first and t>rr:
            #print line
            break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
                #single[disk].append([start[0],t,start[3]])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
for i in sort_whole:
    if i[0]!=cur:
        lats.append([cur,last[1]-start,ds,start])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print float(cnt)/len(lats)
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
# Out:
# 0.0262144053601

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_final3_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        #if tag==14872:
            #print line
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if not first and t>rr:
            #print line
            break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
                #single[disk].append([start[0],t,start[3]])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    print float(sp)/60000000
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
for i in sort_whole:
    if i[0]!=cur:
        lats.append([cur,last[1]-start,ds,start])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print float(cnt)/len(lats)
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
# Out:
# 0.08884635
# 0.0765964666667
# 0.0885298166667
# 0.0898092833333
# 0.0854078833333
# 0.0262144053601

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_final3_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=200000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        #if tag==14872:
            #print line
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if not first and t>rr:
            #print line
            break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            sl[disk].append([start[0],t])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    print float(sp)/60000000
# Out:
# 0.000716533333333
# 0.00078895
# 0.000545966666667
# 0.0007283
# 0.000779

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_sync_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t))
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        #if first:
        #    first_t=t
        #    first=0
        #if tag==14872:
            #print line
        #if first:
        #    if stage==0:
        #        first=0
        #        time0=t
        #        t=0
        #        print time0
        #    else:
        #        continue
        #if not first and t>rr:
            #print line
        #    break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
                #single[disk].append([start[0],t,start[3]])
#print sl[0]
#for i in range(5):
#    print len(sl[i])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    #plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
for i in sort_whole:
    if i[0]!=cur:
        lats.append([cur,last[1]-start,ds,start])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=6477
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
print sort_lats[int(len(sort_lats)*0.8)]
print sort_lats[int(len(sort_lats)*0.9)]
print sort_lats[int(len(sort_lats)*0.99)]
for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print float(cnt)/len(lats)
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    #plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
# Out:
# [6448, 776.0, [1, 0, 1, 0, 0], 394867579382.0]
# [30183, 1166.0, [1, 0, 0, 1, 1], 394876688101.0]
# [62030, 6477.0, [1, 0, 0, 1, 1], 394889228454.0]
# 0.00194377349322

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_sync_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t))
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        #if first:
        #    first_t=t
        #    first=0
        #if tag==14872:
            #print line
        #if first:
        #    if stage==0:
        #        first=0
        #        time0=t
        #        t=0
        #        print time0
        #    else:
        #        continue
        #if not first and t>rr:
            #print line
        #    break
        if tag!=-1:
            whole.append([tag,t,disk])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
                #single[disk].append([start[0],t,start[3]])
#print sl[0]
#for i in range(5):
#    print len(sl[i])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    #plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
for i in sort_whole:
    if i[0]!=cur:
        lats.append([cur,last[1]-start,ds,start])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=1166
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
print sort_lats[int(len(sort_lats)*0.8)]
print sort_lats[int(len(sort_lats)*0.9)]
print sort_lats[int(len(sort_lats)*0.99)]
for j in lats:
    if j[1]>thr:
        if not suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print float(cnt)/len(lats)
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    #plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
# Out:
# [6448, 776.0, [1, 0, 1, 0, 0], 394867579382.0]
# [30183, 1166.0, [1, 0, 0, 1, 1], 394876688101.0]
# [62030, 6477.0, [1, 0, 0, 1, 1], 394889228454.0]
# 0.0220246687724

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_size_parse'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if tag!=-1:
            whole.append([tag,t,disk,addr,stage])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    '''
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    #plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    #ax1.plot(x,y)
    #plt.show()
    '''
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
cur_size=0
for i in sort_whole:
    if i[4]==0:
        cur_size=int(i[2])
    if i[0]!=cur:
        #print cur_size
        lats.append([cur,last[1]-start,ds,start,cur_size])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
p75=sort_lats[int(len(sort_lats)*0.75)][1]
p90=sort_lats[int(len(sort_lats)*0.9)][1]
p99=sort_lats[int(len(sort_lats)*0.99)][1]
print p75,p90,p99

for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
ms_bucket={}
print 'zhulian',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>0:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'spike ratio',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>p99:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'p99 spike ratio',float(cnt)/len(lats)
for j in lats:
    now_ms = float(j[3])
    if now_ms in ms_bucket:
        ms_bucket[now_ms]+=j[4]
    else:
        ms_bucket[now_ms]=j[4]
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p75 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p75 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p90 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p90 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p99 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p99 inburst',float(bcnt)/len(lats)
    
'''
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    #plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
'''
# Out:
# 3808.0 7967.0 11799.0
# zhulian 0.0264529616725
# spike ratio 0.601003484321
# p99 spike ratio 0.00989547038328
# p75 inburst 0.0433170731707
# p90 inburst 0.0144111498258
# p99 inburst 0.00200696864111
# "\nif 1:\n    for i in ret:\n        x.append(i[0])\n        y.append(0)\n        x.append(i[0])\n        y.append(1)\n        x.append(i[1])\n        y.append(1)\n        x.append(i[1])\n        y.append(0)\n    #x.append(2.0)\n    #y.append(0)\n    fig=plt.figure(figsize=(18,1))\n    ax1=fig.add_subplot(111)\n    #ax1.set_title('Latency Distribution',fontsize=30)\n    fs=25\n    #plt.xlim(ll,rr)\n    plt.xticks(fontsize=fs)\n    #plt.xticks(np.arange(0,rr,5000))\n    plt.yticks(fontsize=fs)\n    #plt.yticks(np.arange(0,1.1,1))\n    #plt.ylim(0,2)\n    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)\n    #ax1.set_ylabel('Latency(ms)',fontsize=fs)\n    #ax1.scatter(x,y,s=1,c='b',marker='o')\n    ax1.plot(x,y,color='red')\n    plt.show()\n#print lats\n"

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_size_parse2'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if tag!=-1:
            whole.append([tag,t,disk,addr,stage])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    '''
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    #plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    #ax1.plot(x,y)
    #plt.show()
    '''
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
cur_size=0
for i in sort_whole:
    if i[4]==0:
        cur_size=int(i[2])
    if i[0]!=cur:
        #print cur_size
        lats.append([cur,last[1]-start,ds,start,cur_size])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
p75=sort_lats[int(len(sort_lats)*0.75)][1]
p90=sort_lats[int(len(sort_lats)*0.9)][1]
p99=sort_lats[int(len(sort_lats)*0.99)][1]
print p75,p90,p99

for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
ms_bucket={}
print 'zhulian',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>0:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'spike ratio',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>p99:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'p99 spike ratio',float(cnt)/len(lats)
for j in lats:
    now_ms = float(j[3])
    if now_ms in ms_bucket:
        ms_bucket[now_ms]+=j[4]
    else:
        ms_bucket[now_ms]=j[4]
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p75 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p75 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p90 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p90 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p99 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p99 inburst',float(bcnt)/len(lats)
    
'''
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    #plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
'''
# Out:
# 7000.0 11085.0 20429.0
# zhulian 0.0243865677941
# spike ratio 0.651021884608
# p99 spike ratio 0.00985711701935
# p75 inburst 0.0398504853198
# p90 inburst 0.0146198830409
# p99 inburst 0.00126605172726
# "\nif 1:\n    for i in ret:\n        x.append(i[0])\n        y.append(0)\n        x.append(i[0])\n        y.append(1)\n        x.append(i[1])\n        y.append(1)\n        x.append(i[1])\n        y.append(0)\n    #x.append(2.0)\n    #y.append(0)\n    fig=plt.figure(figsize=(18,1))\n    ax1=fig.add_subplot(111)\n    #ax1.set_title('Latency Distribution',fontsize=30)\n    fs=25\n    #plt.xlim(ll,rr)\n    plt.xticks(fontsize=fs)\n    #plt.xticks(np.arange(0,rr,5000))\n    plt.yticks(fontsize=fs)\n    #plt.yticks(np.arange(0,1.1,1))\n    #plt.ylim(0,2)\n    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)\n    #ax1.set_ylabel('Latency(ms)',fontsize=fs)\n    #ax1.scatter(x,y,s=1,c='b',marker='o')\n    ax1.plot(x,y,color='red')\n    plt.show()\n#print lats\n"

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssd_size_parse2'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
ql=[]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        if tag!=-1:
            whole.append([tag,t,disk,addr,stage])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
            ql.append(q)
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
range_arr=[]
qq=0
for j in ql:
    qq+=j
print 'queue len',float(qq)/len(ql)
qql=sorted(ql)
print 'q p99',qql[int(len(ql)*0.99)]
print 'queue median',qql[int(len(ql)*0.5)]
print 'max:',qql[-1]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    '''
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    #plt.xlim(ll,rr)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    #ax1.plot(x,y)
    #plt.show()
    '''
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
cur_size=0
for i in sort_whole:
    if i[4]==0:
        cur_size=int(i[2])
    if i[0]!=cur:
        #print cur_size
        lats.append([cur,last[1]-start,ds,start,cur_size])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
p75=sort_lats[int(len(sort_lats)*0.75)][1]
p90=sort_lats[int(len(sort_lats)*0.9)][1]
p99=sort_lats[int(len(sort_lats)*0.99)][1]
print p75,p90,p99
abc=0
for j in sort_lats:
    abc+=j[1]
print 'avg',float(abc)/len(sort_lats)
for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
ms_bucket={}
print 'zhulian',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>0:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'spike ratio',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>p75:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'p99 spike ratio',float(cnt)/len(lats)
for j in lats:
    now_ms = float(j[3])
    if now_ms in ms_bucket:
        ms_bucket[now_ms]+=j[4]
    else:
        ms_bucket[now_ms]=j[4]
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p75 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p75 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p90 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p90 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p99 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p99 inburst',float(bcnt)/len(lats)
    
'''
if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    #plt.xlim(ll,rr)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats
'''
# Out:
# queue len 18.1620088093
# q p99 88
# queue median 12
# max: 219
# 7000.0 11085.0 20429.0
# avg 3774.30478688
# zhulian 0.0243865677941
# spike ratio 0.651021884608
# p99 spike ratio 0.239434496895
# p75 inburst 0.0398504853198
# p90 inburst 0.0146198830409
# p99 inburst 0.00126605172726
# "\nif 1:\n    for i in ret:\n        x.append(i[0])\n        y.append(0)\n        x.append(i[0])\n        y.append(1)\n        x.append(i[1])\n        y.append(1)\n        x.append(i[1])\n        y.append(0)\n    #x.append(2.0)\n    #y.append(0)\n    fig=plt.figure(figsize=(18,1))\n    ax1=fig.add_subplot(111)\n    #ax1.set_title('Latency Distribution',fontsize=30)\n    fs=25\n    #plt.xlim(ll,rr)\n    plt.xticks(fontsize=fs)\n    #plt.xticks(np.arange(0,rr,5000))\n    plt.yticks(fontsize=fs)\n    #plt.yticks(np.arange(0,1.1,1))\n    #plt.ylim(0,2)\n    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)\n    #ax1.set_ylabel('Latency(ms)',fontsize=fs)\n    #ax1.scatter(x,y,s=1,c='b',marker='o')\n    ax1.plot(x,y,color='red')\n    plt.show()\n#print lats\n"

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssdpnobit_parse60'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        #if first==0 and t>60000000:
        #    break
        if tag!=-1:
            whole.append([tag,t,disk,addr,stage])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
    x=[]
    y=[]
    #for i in ss:
    #    x.append(i[0])
    #    y.append(i[1])
    for i in sr:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,2.1,0.2))
    plt.xlim(0,1000000)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y)
    plt.show()
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
cur_size=0
for i in sort_whole:
    if i[4]==0:
        cur_size=int(i[2])
    if i[0]!=cur:
        #print cur_size
        lats.append([cur,last[1]-start,ds,start,cur_size])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=2000
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
p75=sort_lats[int(len(sort_lats)*0.75)][1]
p90=sort_lats[int(len(sort_lats)*0.9)][1]
p99=sort_lats[int(len(sort_lats)*0.99)][1]
#print p75,p90,p99

for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
ms_bucket={}
#print 'zhulian',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>0:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
#print 'spike ratio',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>p99:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
#print 'p99 spike ratio',float(cnt)/len(lats)
for j in lats:
    now_ms = float(j[3])
    if now_ms in ms_bucket:
        ms_bucket[now_ms]+=j[4]
    else:
        ms_bucket[now_ms]=j[4]
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p75 and ms_bucket[now_ms]>20:
        bcnt+=1
#print 'p75 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p90 and ms_bucket[now_ms]>20:
        bcnt+=1
#print 'p90 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p99 and ms_bucket[now_ms]>20:
        bcnt+=1
#print 'p99 inburst',float(bcnt)/len(lats)

if 1:
    for i in ret:
        x.append(i[0])
        y.append(0)
        x.append(i[0])
        y.append(1)
        x.append(i[1])
        y.append(1)
        x.append(i[1])
        y.append(0)
    #x.append(2.0)
    #y.append(0)
    fig=plt.figure(figsize=(18,1))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xlim(0,1000000)
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,rr,5000))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,1.1,1))
    #plt.ylim(0,2)
    #ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    #ax1.set_ylabel('Latency(ms)',fontsize=fs)
    #ax1.scatter(x,y,s=1,c='b',marker='o')
    ax1.plot(x,y,color='red')
    plt.show()
#print lats

# %%
import numpy as np
import matplotlib.pyplot as plt
data='/home/ssdpnobit_parse60'
stack=[]
result=[]
idx=4
outfile=open('ssd_out'+str(idx),'w')
whole=[]
threshold=1000
first=1
time0=0
ll=0
#ll=30000000
rr=60000000
def hit(start,lat,arr):
    ed=start+lat
    for i in arr:
        if ed<i[0]:
            return 0
        if max(start,i[0])<min(ed,i[1]):
            return 1
#[cur,last[1]-start,ds,start]
def suffer2(p,arr):
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            return 1
    return 0

def suffer(p,arr):
    spikes=[0 for i in range(5)]
    for i in range(5):
        if hit(p[3],p[1],arr[i]):
            spikes[i]=1
    for i in range(5):
        if p[2][i] and spikes[i]:
            return 0
    for i in range(5):
        if p[2][i]==0 and spikes[i]:
            return 1
    return 0
def cmpf(a,b,k1,k2):
    if(a[k1]!=b[k1]):
        return int(a[k1]-b[k1])
    else:
        return int(a[k2]-b[k2])

stack=[[] for i in range(5)]
#single=[[] for i in range(5)]
sl=[[] for i in range(5)]
with open(data,'r') as fp:
    for line in fp:
        tag,t,sid,stage,addr,disk,_,q=line.split(',')
        tag=int(tag)
        t=(float(t)-time0)
        last_t=t
        sid=long(sid)
        stage=int(stage)
        addr=long(addr)
        disk=int(disk)
        q=int(q)
        if first:
            if stage==0:
                first=0
                time0=t
                t=0
            else:
                continue
        #if first==0 and t>60000000:
        #    break
        if tag!=-1:
            whole.append([tag,t,disk,addr,stage])
        if stage==100 or stage==1 or stage==5:
            stack[disk].append([t,sid,addr,q])
        if stage==101 or stage==2 or stage==6:
            cur=0
            for cur in range(len(stack[disk])):
                if stack[disk][cur][2]==addr:
                    break
            start = stack[disk].pop(cur)
            if (t-start[0])>q*100+100+threshold:
                sl[disk].append([start[0],t])
range_arr=[]
for i in range(5):
    ss=sorted(sl[i],key=lambda x:x[0])
    sr=[ss[0]]
    for i in range(1,len(ss)):
        if ss[i][0]<sr[-1][1]:
            if ss[i][1]>sr[-1][1]:
                sr[-1][1]=ss[i][1]
        else:
            sr.append(ss[i])
    range_arr.append(sr)
    #print sr
#print range_arr[0]

for arr in range_arr:
    sp = 0 
    for k in arr:
        sp+=k[1]-k[0]
    #print float(sp)/(28000000)
sort_whole = sorted(whole,lambda a,b:cmpf(a,b,0,1))
cur=whole[0][0]
start=whole[0][1]
last=whole[0]
ds=[0 for i in range(5)]
lats=[]
cur_size=0
for i in sort_whole:
    if i[4]==0:
        cur_size=int(i[2])
    if i[0]!=cur:
        #print cur_size
        lats.append([cur,last[1]-start,ds,start,cur_size])
        cur=i[0]
        start=i[1]
        ds=[0 for j in range(5)]
    if i[2]<5:
        ds[i[2]]=1
    last=i
thr=5282
cnt=0
ret=[]
x=[]
y=[]
sort_lats=sorted(lats,key=lambda x:x[1])
p75=sort_lats[int(len(sort_lats)*0.75)][1]
p90=sort_lats[int(len(sort_lats)*0.9)][1]
p99=sort_lats[int(len(sort_lats)*0.99)][1]
print p75,p90,p99

for j in lats:
    if j[1]>thr:
        if suffer(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
ms_bucket={}
print 'zhulian',float(cnt)/len(lats)
cnt=0
for j in lats:
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    if j[1]>0:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'spike ratio',float(cnt)/len(lats)
cnt=0
for j in lats:
    if j[1]>p99:
        if suffer2(j,range_arr):
            cnt+=1
            #print j
            ret.append([j[3],j[3]+j[1]])
print 'p99 spike ratio',float(cnt)/len(lats)
for j in lats:
    now_ms = float(j[3])
    if now_ms in ms_bucket:
        ms_bucket[now_ms]+=j[4]
    else:
        ms_bucket[now_ms]=j[4]
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p75 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p75 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p90 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p90 inburst',float(bcnt)/len(lats)
bcnt=0
for j in lats:
    now_ms = float(j[3])
    if j[1]>p99 and ms_bucket[now_ms]>20:
        bcnt+=1
print 'p99 inburst',float(bcnt)/len(lats)
# Out:
# 1283.0 2951.0 5282.0
# zhulian 5.62413880375e-05
# spike ratio 0.549253395574
# p99 spike ratio 0.00905486347403
# p75 inburst 0.0479457833019
# p90 inburst 0.0202750203875
# p99 inburst 0.00194032788729

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_seqw/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.108630412398
# median 0.109
# 99th: 0.124
# 99.99th: 0.506
# 0.682

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_exchange/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 8.01390202849
# median 0.139
# 99th: 136.777
# 99.99th: 461.499
# 480.809

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/consumer_exchange/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>0 and now<120:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xlim(0,40)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 6.71886446817
# median 0.109
# 99th: 159.745
# 99.99th: 1615.273
# 1687.655

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/consumer_exchange_clean/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>0 and now<120:
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,40)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.220844341665
# median 0.109
# 99th: 2.277
# 99.99th: 35.458
# 37.306

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_raid0_exchange/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 2.358583563
# median 0.13
# 99th: 46.694
# 99.99th: 298.198
# 312.951

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_aged_exchange/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 9.69624873021
# median 0.256
# 99th: 141.29
# 99.99th: 501.379
# 556.594

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_aged_exchange2/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 10.1446287473
# median 0.268
# 99th: 166.398
# 99.99th: 490.651
# 534.586

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/consumer_raid0_exchange/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.137652178963
# median 0.111
# 99th: 0.696
# 99.99th: 9.54
# 15.229

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/dc_aged_MSN/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            la.append(latency)
            cnt+=1
            total+=latency
            now=(float(ll[0])-time0)/1000000
            if now>20 and now<120:
                sl.append([now-20,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(15,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.ylim(0,2)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,11,5))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 0.23911961594
# median 0.186
# 99th: 1.322
# 99.99th: 4.657
# 5.167

# %%
#clean_seqw
import numpy as np
import matplotlib.pyplot as plt
for iii in range(1):
    rcd='/root/fusionRAID/results/sdf_exchange_cfq/rcd0'
    sl=[]
    la=[]
    cnt=0
    total=0
    with open(rcd,'r') as fp:
        f1=fp.readline()
        time0=float(f1.split()[0])
        for line in fp:
            ll=line.split()
            latency=float(ll[1])/1000
            now=(float(ll[0])-time0)/1000000
            if now<5000000:
                la.append(latency)
                cnt+=1
                total+=latency
                sl.append([now,latency])
    ss=sorted(sl,key=lambda x:x[0])
    laa=sorted(la)
    print 'avg',float(total)/cnt
    print 'median',laa[int(0.5*len(laa))]
    print '99th:',laa[int(0.99*len(laa))]
    print '99.99th:',laa[int(0.9999*len(laa))]
    print laa[-1]
    x=[]
    y=[]
    for i in ss:
        x.append(i[0])
        y.append(i[1])
    fig=plt.figure(figsize=(10,8))
    ax1=fig.add_subplot(111)
    #ax1.set_title('Latency Distribution',fontsize=30)
    fs=25
    plt.xticks(fontsize=fs)
    #plt.xticks(np.arange(0,61,20))
    plt.yticks(fontsize=fs)
    #plt.yticks(np.arange(0,18,4))
    #plt.ylim(0,2)
    ax1.set_xlabel('Issue Time(s)',fontsize=fs)
    ax1.set_ylabel('Latency(ms)',fontsize=fs)
    ax1.scatter(x,y,s=2,c='b',marker='o')
    #plt.tight_layout()
    #plt.savefig('toshiba_seqw.pdf',format="pdf")
    plt.show()
# Out:
# avg 6.50901699961
# median 0.107
# 99th: 40.92
# 99.99th: 2181.33
# 2523.601
